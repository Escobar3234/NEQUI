# %% [markdown]
# (1)mini nequi
#
# (2)diagrama clase deben estar en el cuaderno
# cuaderno.ipynb
#
# (3)usuario contraseña
# registro
# nombre
# apellido
# clave
# nos permita ingresar saldo
# restar
# creaar una cuenta de ahorro
#
# (4)herencia
#
# (5)minimo 2 usuarios en la plataforma

# %%
class Urti:
    dinero=0
    cuanta_ahorro=0
    def ingresar(self):
        dinero_meter=int(input('ingrese la cantidad de dinero a guardar'))
        self.dinero=self.dinero+dinero_meter
        print(f'Seguardo correctamente su dinero, actualmente tiene $ {self.dinero} en su cuenta')
    def sacar(self):
        dinero_sacar=int(input('ingrese la cantidad de dinero a sacar'))
        while self.dinero<dinero_sacar:
            print('No puede sacar dinero, no cuenta con saldo suficiente ')
            dinero_sacar=int(input(f'tiene $ {self.dinero}, ingrese la cantidad de dinero a sacar'))
        self.dinero=self.dinero-dinero_sacar
        print("se retiro el dinero con exito, cuenta con",self.dinero)


class Usuarios(Urti):
    def __init__(self):
        self.usuario=[]
        self.contraseña=[]
        self.identificacion=[]
        self.nombre=[]
        self.apellido=[]
        self.contraseña_ahorro=[]

    def registrar(self):
        print(" A continuacion pediremos tus datos para crear tus cuentas ")
        self.usuario.append(str(input('ingrese su numero de telefono,sera su numero de usuario')))
        self.contraseña.append(str(input('ingrese una contraseña para su cuenta')))
        self.identificacion.append(str(input('ingrese su identificacion')))
        self.nombre.append(str(input('ingrese su nombre')))
        self.apellido.append(str(input('ingrese su apellido')))
        print('usuario registrado')
        print('\tUsuario:',self.usuario)
        print('\tnombre:',self.nombre,self.apellido,'\n')

    def Mostrar_usuario(self):
        return self.usuario
        
    def verificar_contra(self):
        while True:
            contraseñaaverificar=[]
            contraseñaaverificar.append(str(input('ingrese su contraseña')))
            if contraseñaaverificar==self.contraseña:
                break
        print('contraseña:',contraseñaaverificar)

    def crea_cuenta_ahorro (self):
        self.contraseña_ahorro.append(str(input('se conservaran los datos paara crear su cuenta de ahorro a continuacion digite la contraseña')))
        print(f'Cuenta de ahorro creada\n\tUsuario: {self.usuario} \n\tContraseña: {self.contraseña_ahorro}')
        while True:
            salir_ca=int(input('presione (1) para volver a la cuenta principal'))
            if salir_ca==1:
                break

    

class Ingresar(Usuarios):
    def Entrar(self):
        if opcion_usuario==1:
            print('Usuario:',usuario1.Mostrar_usuario())
            usuario1.verificar_contra()
            print(f'en la cuenta hay $ {self.dinero}')
            while True:
                while True:
                    opcion_realizar=int(input('elija la opcion. (1)guardar dinero (2)sacar dinero (3)crear cuenta de ahorro (4)cerrar seccion'))
                    if opcion_realizar>0 and opcion_realizar<5:
                        break
                if opcion_realizar==1:
                    usuario1.ingresar()
                elif opcion_realizar==2:
                    usuario1.sacar()
                elif opcion_realizar==3:
                    usuario1.crea_cuenta_ahorro()
                    print('está de nuevo en la cuenta principal')
                elif opcion_realizar==4:
                    print('seccion cerrada')
                    break
            

        else:
            print('Usuario:',usuario2.Mostrar_usuario()) 
            usuario2.verificar_contra()
            print(f'en la cuenta hay $ {self.dinero}')
            while True:
                while True:
                    opcion_realizar=int(input('Seleccione. (1) Guardar dinero (2) Sacar dinero (3) Crear cuenta de ahorro (4) Cerrar seccion'))
                    if opcion_realizar>0 and opcion_realizar<5:
                        break
                if opcion_realizar==1:
                    usuario2.ingresar()
                elif opcion_realizar==2:
                    usuario2.sacar()
                elif opcion_realizar==3:
                    usuario2.crea_cuenta_ahorro()
                    print('Está de nuevo en la cuenta principal')
                elif opcion_realizar==4:
                    print('Seccion cerrada')
                    break

usuario1=Ingresar()
usuario2=Ingresar()
print('usuario 1')
usuario1.registrar()
print('usuario 2')
usuario2.registrar()

print('Bienvenido a Urti')
while True:
    while True:
        opcion_usuario=int(input('¿ En que usuario decea ingresar? (1 o 2),puede presionar (0) para salir de "Urti"'))
        if opcion_usuario<3:
            break
    if opcion_usuario==1:
        usuario1.Entrar()
    elif opcion_usuario==2:
        usuario2.Entrar()
    else:
        break
# Out:
# usuario 1
#  A continuacion pediremos tus datos para crear tus cuentas
# usuario registrado
# 	Usuario: ['3114486203']
# 	nombre: ['juan '] ['gutierres']
#
# usuario 2
#  A continuacion pediremos tus datos para crear tus cuentas
# usuario registrado
# 	Usuario: ['3227112227']
# 	nombre: ['pedro'] ['perez']
#
# Bienvenido a Urti
# Usuario: ['3114486203']
# contraseña: ['juan11']
# en la cuenta hay $ 0
# Seguardo correctamente su dinero, actualmente tiene $ 10000 en su cuenta
# seccion cerrada
# Usuario: ['3227112227']
# contraseña: ['jean11']
# en la cuenta hay $ 0
# Seguardo correctamente su dinero, actualmente tiene $ 10000 en su cuenta
# Seccion cerrada
# Usuario: ['3114486203']
# contraseña: ['juan11']
# en la cuenta hay $ 10000
# se retiro el dinero, cuenta con 5000
# seccion cerrada

# %% [markdown]
# DIAGRAMA DE FLUJO/h
# <img src="Diagrama Urti.png" alt="Getting started" />
